# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghost1499/unet_segmentation/blob/unet-segmentation/unet_train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # U-net segmentation on carvana dataset

# %% [markdown]
# ## In Colab-only code

# %%
try:
    import google.colab

    IN_COLAB = True
except:
    IN_COLAB = False

# %%
if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/drive")

# %%
import os

if IN_COLAB:
    from pathlib import Path

    project_dir = (
        r"/content/drive/MyDrive/Colab Notebooks/unet0 carvana/unet_segmentation old"
    )
else:
    project_dir = r"c:\CSF\programs\Segmentation_cont"
os.chdir(project_dir)
print(os.getcwd())
# Out:
# c:\CSF\programs\Segmentation_cont

# %%
if IN_COLAB:
    from google.colab import files

    files.view(project_dir)

# %%
# if IN_COLAB:
import sys

sys.path.append(project_dir + "/src")

# %%
print(*sys.path, sep="\n")
# Out:
# c:\CSF\programs\Segmentation_cont\src\scripts
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311\python311.zip
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311\DLLs
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311\Lib
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311
#
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311\Lib\site-packages
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311\Lib\site-packages\win32
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311\Lib\site-packages\win32\lib
# c:\Users\zgstv\AppData\Local\Programs\Python\Python311\Lib\site-packages\Pythonwin
# c:\CSF\programs\Segmentation_cont/src

# %%
if IN_COLAB:
    # !pip install --upgrade keras

# %% [markdown]
# ## Git section

# %%
# !git status
# Out:
# Refresh index: 100% (15/15), done.
# On branch unet-segmentation
# Your branch and 'origin/unet-segmentation' have diverged,
# and have 1 and 19 different commits each, respectively.
#   (use "git pull" to merge the remote branch into yours)
#
# It took 6.73 seconds to compute the branch ahead/behind values.
# You can use '--no-ahead-behind' to avoid this.
#
# You have unmerged paths.
#   (fix conflicts and run "git commit")
#   (use "git merge --abort" to abort the merge)
#
# Changes to be committed:
# 	modified:   .gitignore
# 	deleted:    src/Contour_step.py
# 	modified:   src/configs/ds_prepare_config.py
# 	modified:   src/configs/training_config.py
# 	new file:   src/datastore.py
# 	deleted:    src/evaluate.py
# 	new file:   src/evaluate_script.py
# 	deleted:    src/google_colab_data.py
# 	deleted:    src/image_proccess.py
# 	deleted:    src/load.py
# 	new file:   src/load_samples.py
# 	deleted:    src/loss_fun.py
# 	deleted:    src/make_patches.py
# 	deleted:    src/metrics.py
# 	modified:   src/models.py
# 	deleted:    src/my_fun_new_colab.py
# 	deleted:    src/unet_segm_script.py
# 	modified:   src/utils/io_utils.py
#
# Unmerged paths:
#   (use "git add <file>..." to mark resolution)
# 	both modified:   src/unet_train_colab.ipynb

# %%
# !git log
# Out:
# commit 2123424830ac60affd470c749ebae87b2dc42810 (HEAD -> unet-segmentation)
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Tue Jan 23 18:59:22 2024 +0000
#
#     add git section
#
# commit cc3dd4e4cff8d5d5607002c881853ba3e9892cb0
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Sat Jan 20 20:31:33 2024 +0000
#
#     add batch normalization to model
#
# commit 7c44574d8c98d9d404faea217b0764a415cfae55
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Sat Jan 20 20:30:37 2024 +0000
#
#     fix RNG dependency
#
# commit 202e4a59a6d2903c6373da2ac7f1a1ad378b56e3
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Sat Jan 20 20:29:08 2024 +0000
#
#     change main script to .ipynb file for running in colab
#
# commit 6a7904108ac31f91315a7554e1281a248ea9b033
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 18 00:49:39 2024 +0300
#
#     refactor training model function
#
# commit 29d1ce12e9adcef97c3686c42aa5f05f047b44c8
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 18 00:04:40 2024 +0300
#
#     move helper functions to corresponding files
#
# commit d7e07772770cffc4234e4c12f3b4c19667992107
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Wed Jan 17 22:53:51 2024 +0300
#
#     fix model training big negative loss error
#
# commit bfd0c087c403b7f9131b86405e7af5fa8b184c07
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Mon Jan 15 21:24:19 2024 +0300
#
#     minor training fixes
#
# commit bc8a06b213d68db06b37684b9f6ad3a78c1f0a90
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Mon Jan 15 21:12:03 2024 +0300
#
#     add compile configs
#
# commit c0243677519f74da6198c5d7f28db202dbc575c4
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Mon Jan 15 20:28:37 2024 +0300
#
#     decrease image target size
#
# commit 70eba273f657263729eb6d9d4fc1d46348846811
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Mon Jan 15 00:55:39 2024 +0300
#
#     fix shuffle data
#
# commit 72ae438bbe5fd91628c7d4d82c2ff4d304e04c8d
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Sun Jan 14 22:55:50 2024 +0300
#
#     add configs
#
# commit 7bca433e17aa80b73ca1ee3e601e994089de4f68
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Sun Jan 14 22:55:35 2024 +0300
#
#     add unet segmentation
#
# commit d6e291c18b6df282965f219a48645dc633d74753
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Sun Jan 14 22:55:12 2024 +0300
#
#     remove resizing layer
#
# commit 8681c296972e6a8f32090feb624951b0ec4fe34b
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Fri Jan 12 19:22:13 2024 +0300
#
#     add resizing layer to unet0
#
# commit 128a61351cfefb9c8a53a236733e72f70f0c6d48
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 20:25:07 2024 +0300
#
#     remove model_name paremeter from createUNetModel_My
#
# commit 25d2af957dec7b53cd0eb04b7bab7c67b0f0b697
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 20:12:16 2024 +0300
#
#     other fixes
#
# commit 78048167d6a8a3b07c80e702404a577a1115848f
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 20:10:20 2024 +0300
#
#     create models module
#
# commit 6e059212567677782e4a72f6cb4642e38cb81e93
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 20:05:39 2024 +0300
#
#     create metrics module
#
# commit f71823a123a70e377db5c82fc316aabc83a57ebb
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 20:03:38 2024 +0300
#
#     create utils module
#
# commit 6c404f32799342c60b25358d15146e878c1479ba
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 20:03:24 2024 +0300
#
#     create evaluate module
#
# commit 717f80638cfe44c73779a70f192f8fa8ec1063b5
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 19:57:38 2024 +0300
#
#     create image_process module
#
# commit a21b297354ded5124de9a117ae632b6d0b8f4b2a
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 19:57:02 2024 +0300
#
#     create load module
#
# commit a44c04b1a6ce49af9fe2b1055bd95724f1829022
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Thu Jan 11 19:53:44 2024 +0300
#
#     create make_patches module
#
# commit 845135b97597c294d74cbe8f23bee16095048eec
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Wed Jan 10 20:31:29 2024 +0300
#
#     extend .gitignore
#
# commit f2b8dc060bec468d4d0eceb54faf2c0c3b5b6845
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Wed Jan 10 20:29:32 2024 +0300
#
#     create models module
#
# commit f2f47cdf84711b43334eecedae868cc3fddec48e
# Author: Ghost1499 <zgstv@yandex.ru>
# Date:   Sun Jan 7 23:46:54 2024 +0300
#
#     init

# %%
# !git add src/unet_train_colab.ipynb

# %%
# !git commit --amend -m "add git section"
# Out:
# [unet-segmentation c2ffee6] add git section
#  Date: Tue Jan 23 18:59:22 2024 +0000
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite src/unet_train_colab.ipynb (71%)

# %%
# !git remote -v
# Out:
# origin	https://Ghost1499:ghp_50MbhVrA851tqjU7AZ3DRMlSk8cIA00Wabr@github.com/Ghost1499/unet_segmentation.git (fetch)
# origin	https://Ghost1499:ghp_50MbhVrA851tqjU7AZ3DRMlSk8cIA00Wabr@github.com/Ghost1499/unet_segmentation.git (push)

# %%
# !git remote remove origin

# %%
from google.colab import userdata

token = userdata.get("GITHUB_TOKEN")
# !git remote set-url origin "https://Ghost1499:{token}@github.com/Ghost1499/unet_segmentation.git"
# Out:
# <html>
# <head><title>301 Moved Permanently</title></head>
# <body>
# <center><h1>301 Moved Permanently</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>

# %%
# !git config --global user.email "zgstv@yandex.ru"
# !git config --global user.name "Ghost1499"
# !git config --global user.password $token

# %%
# !git push
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/Ghost1499/unet_segmentation.git/'

# %%
# !git config -l
# Out:
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# user.email=zgstv@yandex.ru
# user.name=Ghost1499
# user.token=ghp_50MbhVrA851tqjU7AZ3DRMlSk8cIA00Wabr
# user.password=ghp_50MbhVrA851tqjU7AZ3DRMlSk8cIA00Wabr
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://Ghost1499:ghp_50MbhVrA851tqjU7AZ3DRMlSk8cIA00Wabr@github.com/Ghost1499/unet_segmentation.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.unet-segmentation.remote=origin
# branch.unet-segmentation.merge=refs/heads/unet-segmentation

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

import numpy as np
import keras
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint, TensorBoard

from configs import io_config, model_config, training_config, ds_prepare_config
from configs.training_config import COMPILE_CONFIGS
from utils.io_utils import save_model
from datastore import make_train_datastore, make_val_datastore

# %% [markdown]
# ## Functions

# %%
# images, masks = get_sample_paths(
#         io_config.TRAIN_IMAGES_DIR, io_config.TRAIN_MASKS_DIR, True
#     )
# print(*(list(zip(images, masks))[:10]),sep='\n')

# %%
# ds = get_dataset(io_config.TRAIN_IMAGES_DIR, io_config.TRAIN_MASKS_DIR)
# image, mask = next(ds.take(1).as_numpy_iterator())
# from skimage.io import imshow, show
# imshow(image)
# show()
# imshow(mask)
# show()

# %% [markdown]
# ## Train model function

# %%
def train_model(model_name):
    with open(io_config.MODEL_SAVE_DIR / f"{model_name}_architecture.json") as f:
        json_model = f.read()
    model: keras.models.Model = model_from_json(json_model)
    # image_shape = get_images_shapes(io_config.TRAIN_IMAGES_DIR)

    train_ds = make_train_datastore(
        is_mini=True, mask_type="contours_insensitive"
    ).dataset
    val_ds = make_val_datastore(is_mini=True, mask_type="contours_insensitive").dataset

    optimizer = keras.optimizers.Adam(
        learning_rate=training_config.LEARNING_RATE,
        beta_1=0.9,
        beta_2=0.999,
        amsgrad=False,
    )  # ,decay=1e-6)

    comp_config = COMPILE_CONFIGS[model_config.OUT_SIZE]
    comp_config["optimizer"] = optimizer
    comp_config["run_eagerly"] = training_config.DEBUG_MODEL
    model.compile(**comp_config)

    checkpointer = ModelCheckpoint(
        filepath=str(io_config.CHECKPOINTS_SAVE_DIR / f"{model_name}_{{epoch}}.keras"),
        monitor="val_accuracy",
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
    )
    tboard = TensorBoard(io_config.TENSORBOARD_LOG_DIR)  # type: ignore
    model.fit(
        train_ds,
        epochs=training_config.EPOCHS,
        callbacks=[checkpointer, tboard],
        validation_data=val_ds,
        shuffle=False,
    )
    model.save(io_config.MODEL_SAVE_DIR / f"{model_name}.keras")

# %% [markdown]
# ## **Entry point**

# %%
model_name = "unet0 contours insensitive"
save_model(model_name)
train_model(model_name)
# Out:
# Model: "functional_1"
# +--------------------------------------------------------------------------+
# |                   |                 |  Param |                   |       |
# | Layer (type)      | Output Shape    |      # | Connected to      | Trai… |
# |-------------------+-----------------+--------+-------------------+-------|
# | input_layer       | (None, 160,     |      0 | -                 |   -   |
# | (InputLayer)      | 160, 3)         |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d (Conv2D)   | (None, 160,     |    896 | input_layer[0][0] |   Y   |
# |                   | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 160,     |    128 | conv2d[0][0]      |   Y   |
# | (BatchNormalizat… | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation        | (None, 160,     |      0 | batch_normalizat… |   -   |
# | (Activation)      | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_1 (Conv2D) | (None, 160,     |  9,248 | activation[0][0]  |   Y   |
# |                   | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 160,     |    128 | conv2d_1[0][0]    |   Y   |
# | (BatchNormalizat… | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_1      | (None, 160,     |      0 | batch_normalizat… |   -   |
# | (Activation)      | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | max_pooling2d     | (None, 80, 80,  |      0 | activation_1[0][… |   -   |
# | (MaxPooling2D)    | 32)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_2 (Conv2D) | (None, 80, 80,  | 18,496 | max_pooling2d[0]… |   Y   |
# |                   | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 80, 80,  |    256 | conv2d_2[0][0]    |   Y   |
# | (BatchNormalizat… | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_2      | (None, 80, 80,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_3 (Conv2D) | (None, 80, 80,  | 36,928 | activation_2[0][… |   Y   |
# |                   | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 80, 80,  |    256 | conv2d_3[0][0]    |   Y   |
# | (BatchNormalizat… | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_3      | (None, 80, 80,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | max_pooling2d_1   | (None, 40, 40,  |      0 | activation_3[0][… |   -   |
# | (MaxPooling2D)    | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_4 (Conv2D) | (None, 40, 40,  | 73,856 | max_pooling2d_1[… |   Y   |
# |                   | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 40, 40,  |    512 | conv2d_4[0][0]    |   Y   |
# | (BatchNormalizat… | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_4      | (None, 40, 40,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_5 (Conv2D) | (None, 40, 40,  | 147,5… | activation_4[0][… |   Y   |
# |                   | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 40, 40,  |    512 | conv2d_5[0][0]    |   Y   |
# | (BatchNormalizat… | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_5      | (None, 40, 40,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | max_pooling2d_2   | (None, 20, 20,  |      0 | activation_5[0][… |   -   |
# | (MaxPooling2D)    | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_6 (Conv2D) | (None, 20, 20,  | 295,1… | max_pooling2d_2[… |   Y   |
# |                   | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 20, 20,  |  1,024 | conv2d_6[0][0]    |   Y   |
# | (BatchNormalizat… | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_6      | (None, 20, 20,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_7 (Conv2D) | (None, 20, 20,  | 590,0… | activation_6[0][… |   Y   |
# |                   | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 20, 20,  |  1,024 | conv2d_7[0][0]    |   Y   |
# | (BatchNormalizat… | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_7      | (None, 20, 20,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | max_pooling2d_3   | (None, 10, 10,  |      0 | activation_7[0][… |   -   |
# | (MaxPooling2D)    | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_8 (Conv2D) | (None, 10, 10,  | 1,180… | max_pooling2d_3[… |   Y   |
# |                   | 512)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 10, 10,  |  2,048 | conv2d_8[0][0]    |   Y   |
# | (BatchNormalizat… | 512)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_8      | (None, 10, 10,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 512)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_9 (Conv2D) | (None, 10, 10,  | 2,359… | activation_8[0][… |   Y   |
# |                   | 512)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 10, 10,  |  2,048 | conv2d_9[0][0]    |   Y   |
# | (BatchNormalizat… | 512)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_9      | (None, 10, 10,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 512)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | up_sampling2d     | (None, 20, 20,  |      0 | activation_9[0][… |   -   |
# | (UpSampling2D)    | 512)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_10         | (None, 20, 20,  | 524,5… | up_sampling2d[0]… |   Y   |
# | (Conv2D)          | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | concatenate       | (None, 20, 20,  |      0 | activation_7[0][… |   -   |
# | (Concatenate)     | 512)            |        | conv2d_10[0][0]   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_11         | (None, 20, 20,  | 1,179… | concatenate[0][0] |   Y   |
# | (Conv2D)          | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 20, 20,  |  1,024 | conv2d_11[0][0]   |   Y   |
# | (BatchNormalizat… | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_10     | (None, 20, 20,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_12         | (None, 20, 20,  | 590,0… | activation_10[0]… |   Y   |
# | (Conv2D)          | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 20, 20,  |  1,024 | conv2d_12[0][0]   |   Y   |
# | (BatchNormalizat… | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_11     | (None, 20, 20,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | up_sampling2d_1   | (None, 40, 40,  |      0 | activation_11[0]… |   -   |
# | (UpSampling2D)    | 256)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_13         | (None, 40, 40,  | 131,2… | up_sampling2d_1[… |   Y   |
# | (Conv2D)          | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | concatenate_1     | (None, 40, 40,  |      0 | activation_5[0][… |   -   |
# | (Concatenate)     | 256)            |        | conv2d_13[0][0]   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_14         | (None, 40, 40,  | 295,0… | concatenate_1[0]… |   Y   |
# | (Conv2D)          | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 40, 40,  |    512 | conv2d_14[0][0]   |   Y   |
# | (BatchNormalizat… | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_12     | (None, 40, 40,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_15         | (None, 40, 40,  | 147,5… | activation_12[0]… |   Y   |
# | (Conv2D)          | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 40, 40,  |    512 | conv2d_15[0][0]   |   Y   |
# | (BatchNormalizat… | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_13     | (None, 40, 40,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | up_sampling2d_2   | (None, 80, 80,  |      0 | activation_13[0]… |   -   |
# | (UpSampling2D)    | 128)            |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_16         | (None, 80, 80,  | 32,832 | up_sampling2d_2[… |   Y   |
# | (Conv2D)          | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | concatenate_2     | (None, 80, 80,  |      0 | activation_3[0][… |   -   |
# | (Concatenate)     | 128)            |        | conv2d_16[0][0]   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_17         | (None, 80, 80,  | 73,792 | concatenate_2[0]… |   Y   |
# | (Conv2D)          | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 80, 80,  |    256 | conv2d_17[0][0]   |   Y   |
# | (BatchNormalizat… | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_14     | (None, 80, 80,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_18         | (None, 80, 80,  | 36,928 | activation_14[0]… |   Y   |
# | (Conv2D)          | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 80, 80,  |    256 | conv2d_18[0][0]   |   Y   |
# | (BatchNormalizat… | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_15     | (None, 80, 80,  |      0 | batch_normalizat… |   -   |
# | (Activation)      | 64)             |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | up_sampling2d_3   | (None, 160,     |      0 | activation_15[0]… |   -   |
# | (UpSampling2D)    | 160, 64)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_19         | (None, 160,     |  8,224 | up_sampling2d_3[… |   Y   |
# | (Conv2D)          | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | concatenate_3     | (None, 160,     |      0 | activation_1[0][… |   -   |
# | (Concatenate)     | 160, 64)        |        | conv2d_19[0][0]   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_20         | (None, 160,     | 18,464 | concatenate_3[0]… |   Y   |
# | (Conv2D)          | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 160,     |    128 | conv2d_20[0][0]   |   Y   |
# | (BatchNormalizat… | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_16     | (None, 160,     |      0 | batch_normalizat… |   -   |
# | (Activation)      | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_21         | (None, 160,     |  9,248 | activation_16[0]… |   Y   |
# | (Conv2D)          | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | batch_normalizat… | (None, 160,     |    128 | conv2d_21[0][0]   |   Y   |
# | (BatchNormalizat… | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_17     | (None, 160,     |      0 | batch_normalizat… |   -   |
# | (Activation)      | 160, 32)        |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | conv2d_22         | (None, 160,     |     33 | activation_17[0]… |   Y   |
# | (Conv2D)          | 160, 1)         |        |                   |       |
# |-------------------+-----------------+--------+-------------------+-------|
# | activation_18     | (None, 160,     |      0 | conv2d_22[0][0]   |   -   |
# | (Activation)      | 160, 1)         |        |                   |       |
# +--------------------------------------------------------------------------+
#  Total params: 7,771,873 (29.65 MB)
#  Trainable params: 7,765,985 (29.62 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/10

# %% [markdown]
# ## Tensorboard

# %%
# %load_ext tensorboard
# %tensorboard --logdir data/logs

# %% [markdown]
# Точность за 8 эпох - 0,9942/0,9928

# %% [markdown]
# ## **TODO**
#
#
# 1. ~~Закомитить изменения в новую ветку colab_training~~
# 2. Изменить метрику оценки на meaniou или dice
# 3. ~~Посмотреть логи tensoboard~~
# 4. ~~Оценить лучшую модель~~ 0,98 mean iou
# 5. Переделать набор для определения контуров
# 6. Добавить оповещение об окончании обучения
